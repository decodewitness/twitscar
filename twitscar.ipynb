# %% [markdown]
# #Twitter Scrapes

# %%
from google.colab import drive
drive.mount('gdrive')
# Out:
# Mounted at gdrive

# %%
# %cd /content/gdrive/My Drive/covertsniper
# Out:
# /content/gdrive/My Drive/covertsniper

# %%
#%mkdir datasets

# %%
# !pwd
# Out:
# /content/gdrive/My Drive/covertsniper

# %%
#!ls

# %%
#!ls datasets

# %%
# !pip install nest-asyncio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting nest-asyncio
#   Downloading nest_asyncio-1.5.5-py3-none-any.whl (5.2 kB)
# Installing collected packages: nest-asyncio
# Successfully installed nest-asyncio-1.5.5

# %%
#!pip3 install --user --upgrade git+https://github.com/twintproject/twint.git@origin/master#egg=twint
#!pip3 install twint

# Upgrade Twint
# !pip3 install --upgrade -e git+https://github.com/twintproject/twint.git@origin/master#egg=twint
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining twint from git+https://github.com/twintproject/twint.git@origin/master#egg=twint
#   Cloning https://github.com/twintproject/twint.git (to revision origin/master) to ./src/twint
#   Running command git clone -q https://github.com/twintproject/twint.git '/content/gdrive/My Drive/covertsniper/src/twint'
#   WARNING: Did not find branch or tag 'origin/master', assuming revision or ref.
#   Running command git checkout -q origin/master
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from twint) (3.8.1)
# Collecting aiodns
#   Downloading aiodns-3.0.0-py3-none-any.whl (5.0 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from twint) (4.6.3)
# Collecting cchardet
#   Downloading cchardet-2.1.7-cp37-cp37m-manylinux2010_x86_64.whl (263 kB)
#      |████████████████████████████████| 263 kB 2.8 MB/s
# Collecting dataclasses
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Collecting elasticsearch
#   Downloading elasticsearch-8.4.0-py3-none-any.whl (385 kB)
#      |████████████████████████████████| 385 kB 41.3 MB/s
# Requirement already satisfied: pysocks in /usr/local/lib/python3.7/dist-packages (from twint) (1.7.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from twint) (1.3.5)
# Collecting aiohttp_socks
#   Downloading aiohttp_socks-0.7.1-py3-none-any.whl (9.3 kB)
# Collecting schedule
#   Downloading schedule-1.1.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: geopy in /usr/local/lib/python3.7/dist-packages (from twint) (1.17.0)
# Collecting fake-useragent
#   Downloading fake-useragent-0.1.11.tar.gz (13 kB)
# Collecting googletransx
#   Downloading googletransx-2.4.2.tar.gz (13 kB)
# Collecting pycares>=4.0.0
#   Downloading pycares-4.2.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#      |████████████████████████████████| 288 kB 43.3 MB/s
# Requirement already satisfied: cffi>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pycares>=4.0.0->aiodns->twint) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.5.0->pycares>=4.0.0->aiodns->twint) (2.21)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->twint) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->twint) (1.2.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->twint) (2.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->twint) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->twint) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->twint) (6.0.2)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->twint) (0.13.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->twint) (22.1.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from aiohttp->twint) (4.1.1)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.7/dist-packages (from yarl<2.0,>=1.0->aiohttp->twint) (2.10)
# Collecting python-socks[asyncio]<3.0.0,>=2.0.0
#   Downloading python_socks-2.0.3-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 4.5 MB/s
# Collecting elastic-transport<9,>=8
#   Downloading elastic_transport-8.4.0-py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 4.1 MB/s
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from elastic-transport<9,>=8->elasticsearch->twint) (2022.6.15)
# Collecting urllib3<2,>=1.26.2
#   Downloading urllib3-1.26.12-py2.py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 45.5 MB/s
# Requirement already satisfied: geographiclib<2,>=1.49 in /usr/local/lib/python3.7/dist-packages (from geopy->twint) (1.52)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from googletransx->twint) (2.23.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas->twint) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->twint) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->twint) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->twint) (1.15.0)
# Collecting requests
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 730 kB/s
# Building wheels for collected packages: fake-useragent, googletransx
#   Building wheel for fake-useragent (setup.py) ... done
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-py3-none-any.whl size=13502 sha256=ffe8e83036ffc3c4184ed851a7e751d371cf63c88d4aef7381448ca91e56d8f1
#   Stored in directory: /root/.cache/pip/wheels/ed/f7/62/50ab6c9a0b5567267ab76a9daa9d06315704209b2c5d032031
#   Building wheel for googletransx (setup.py) ... done
#   Created wheel for googletransx: filename=googletransx-2.4.2-py3-none-any.whl size=15968 sha256=c9e20c5cb53d3fd7bc5371841daeaa182a2f5e58cb2bf259c9c7d682e372fac1
#   Stored in directory: /root/.cache/pip/wheels/66/d5/b1/31104b338f7fd45aa8f7d22587765db06773b13df48a89735f
# Successfully built fake-useragent googletransx
# Installing collected packages: urllib3, python-socks, requests, pycares, elastic-transport, schedule, googletransx, fake-useragent, elasticsearch, dataclasses, cchardet, aiohttp-socks, aiodns, twint
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Running setup.py develop for twint
# Successfully installed aiodns-3.0.0 aiohttp-socks-0.7.1 cchardet-2.1.7 dataclasses-0.6 elastic-transport-8.4.0 elasticsearch-8.4.0 fake-useragent-0.1.11 googletransx-2.4.2 pycares-4.2.2 python-socks-2.0.3 requests-2.28.1 schedule-1.1.0 twint-2.1.21 urllib3-1.26.12

# %%
# !mv src/twint .
# !rm -r src

# %%
# %load_ext autoreload
# %autoreload
import sys
sys.path.append("twint/")

# %%
import twint
import pandas as pd
import nest_asyncio
nest_asyncio.apply()

# %%
c = twint.Config()
c.Pandas = True
c.Store_csv = True
#c.Username = "knowledge"
c.Search = "#artificial intelligence"
c.Limit = 1500
c.Since = "2022-07-09"
c.Until = "2022-08-09"
c.Lang = 'en'

# %%
twint.run.Search(c)
# Out:
# 1556788607364603904 2022-08-08 23:45:02 +0000 <allauthor> "THE AI SLAVE" transpires in a future gay society where #artificial #intelligence has influenced and transformed the age gap relationship between Ada an older lesbian and Katz a younger lesbian.  @home Buy Now --&gt;  https://t.co/dphnLR271g  https://t.co/X9EY1IM4pH
# 1556777844029755394 2022-08-08 23:02:16 +0000 <marklarsen85> Watch every episode of the @lexfridman podcast. It was briefly #Artificial #Intelligence #Podcast, but you will increase general intelligence after consuming regularly. #MoneyBackGuarantee
# 1556766547087081473 2022-08-08 22:17:22 +0000 <byLilyV> #FEATURED #COURSES  Machine Learning, Data Science and Deep Learning with Python  Complete hands-on #machine #learning tutorial with #data #science, #Tensorflow, #artificial #intelligence, and neural networks   https://t.co/PaHDf4fIL2  #python #100daysofcode #coding #udemy  https://t.co/NfScoEm0zG
# 1556762614499262470 2022-08-08 22:01:45 +0000 <rafael52987> #startup #sensors #VR #SaaS #dataviz #Artificial #Intelligence- #programming  #CodeNewbie #reactjs #bugbounty #DataScience #infosec #gamedev #BigData #Coding #DataScience #NeuralNetworks  #OpenSource #AI #numpy #Algebra #DEVCommunity #codinglife @PublicHealthBot #PublicHealth
# 3  2022-08-08 22:01:45    +0000
# 4  2022-08-08 21:48:11    +0000
#
#                                                tweet language  \
# 0  "THE AI SLAVE" transpires in a future gay soci...       en
# 1  Watch every episode of the @lexfridman podcast...       en
# 2  #FEATURED #COURSES  Machine Learning, Data Sci...       en
# 3  #startup #sensors #VR #SaaS #dataviz #Artifici...      und
# 4  Retweet selected by the  https://t.co/11ojAZA3...       en
#
#                                             hashtags cashtags  ...  geo  \
# 0                         [artificial, intelligence]       []  ...
# 1  [artificial, intelligence, podcast, moneybackg...       []  ...
# 2  [featured, courses, machine, learning, data, s...       []  ...
# 3  [startup, sensors, vr, saas, dataviz, artifici...       []  ...
# 4                                       [artificial]       []  ...
#
#   source user_rt_id user_rt  retweet_id reply_to retweet_date translate  \
# 0                                             []
# 1                                             []
# 2                                             []
# 3                                             []
# 4                                             []
#
#   trans_src  trans_dest
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 38 columns]

# %%
twint.storage.panda.Tweets_df.count()
# Out:
# id                 36
# conversation_id    36
# created_at         36
# date               36
# timezone           36
# place              36
# tweet              36
# language           36
# hashtags           36
# cashtags           36
# user_id            36
# user_id_str        36
# username           36
# name               36
# day                36
# hour               36
# link               36
# urls               36
# photos             36
# video              36
# thumbnail          36
# retweet            36
# nlikes             36
# nreplies           36
# nretweets          36
# quote_url          36
# search             36
# near               36
# geo                36
# source             36
# user_rt_id         36
# user_rt            36
# retweet_id         36
# reply_to           36
# retweet_date       36
# translate          36
# trans_src          36
# trans_dest         36
# dtype: int64

# %%
twint.storage.panda.Tweets_df['tweet'].count()
# Out:
# 36

# %%
twint.storage.panda.Tweets_df['tweet'][10]
# Out:
# "Retweet selected by the  https://t.co/11ojAZA3Wf team |  This Year's Hottest Job Involves Artificial Intelligence #artificial-intelligence  https://t.co/UWjOp2wn6K  https://t.co/xoyuyph4RN"

# %%
# !ls
# Out:
# 'artificial intelligence.csv'   datasets   joke.csv   twint

# %%
twint.storage.panda.Tweets_df.to_csv('artificial intelligence.csv')
# !cp 'artificial intelligence.csv' "gdrive/My Drive/covertsniper/artificial intelligence.csv"
# Out:
# cp: cannot create regular file 'gdrive/My Drive/covertsniper/artificial intelligence.csv': No such file or directory

# %%
# %rm 'artificial intelligence.csv'

# %%
df = pd.DataFrame(twint.storage.panda.Tweets_df['tweet'])

# %%
df.head()
# Out:
#                                                tweet
# 0  "THE AI SLAVE" transpires in a future gay soci...
# 1  Watch every episode of the @lexfridman podcast...
# 2  #FEATURED #COURSES  Machine Learning, Data Sci...
# 3  #startup #sensors #VR #SaaS #dataviz #Artifici...
# 4  Retweet selected by the  https://t.co/11ojAZA3...

# %%
df.shape
# Out:
# (36, 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tweet   36 non-null     object
# dtypes: object(1)
# memory usage: 416.0+ bytes

# %%
df['tweet'].isnull().sum()
# Out:
# 0

# %%
import re

# %%
def myfunc(text):
    # Removing Square Brackets and Extra Spaces
    text = re.sub(r'\[[0-9]*\]', ' ', text)
    # Removing hashtags
    text = re.sub(r'#\w+', ' ', text)
    # Removing brackets
    text = re.sub(r'&lt;', ' ', text)
    text = re.sub(r'&gt;', ' ', text)
    # Removing usertags
    text = re.sub(r'\@\w+', ' ', text)
    # Removing links
    text = re.sub(r'https://(\w+)(\.\w+)*(\.)(\w){2,3}(/)*(\w|\d)*', ' ', text)
    #any whitespace character \s+
    text = re.sub(r'\s+', ' ', text)
    # Removing special characters and digits
    formatted_text = re.sub('[^a-zA-Z]', ' ', text )
    #any whitespace character \s+
    formatted_text = re.sub(r'\s+', ' ', formatted_text)
    return formatted_text

# %%
df['clean_tweets'] = df['tweet'].apply(myfunc)

# %%
# clean_users(twint.storage.panda.Tweets_df['tweet'][10])

# %%
# clean_strings(twint.storage.panda.Tweets_df['tweet'][11])

# %%
# df['clean_tweets'] = df['tweet'].apply(clean_users)
# df['clean_tweets'] = df['tweet'].apply(clean_strings)
# df['clean_tweets'] = df['tweet'].apply(clean_hashtags)

# %%
df.head()
# Out:
#                                                tweet  \
# 0  "THE AI SLAVE" transpires in a future gay soci...
# 1  Watch every episode of the @lexfridman podcast...
# 2  #FEATURED #COURSES  Machine Learning, Data Sci...
# 3  #startup #sensors #VR #SaaS #dataviz #Artifici...
# 4  Retweet selected by the  https://t.co/11ojAZA3...
#
#                                         clean_tweets
# 0   THE AI SLAVE transpires in a future gay socie...
# 1  Watch every episode of the podcast It was brie...
# 2   Machine Learning Data Science and Deep Learni...
# 3
# 4  Retweet selected by the team Best Robotics and...

# %%
df['tweet'][0]
# Out:
# '"THE AI SLAVE" transpires in a future gay society where #artificial #intelligence has influenced and transformed the age gap relationship between Ada an older lesbian and Katz a younger lesbian.  @home Buy Now --&gt;  https://t.co/dphnLR271g  https://t.co/X9EY1IM4pH'

# %%
df['clean_tweets'][0]
# Out:
# ' THE AI SLAVE transpires in a future gay society where has influenced and transformed the age gap relationship between Ada an older lesbian and Katz a younger lesbian Buy Now '

# %%
import numpy as np
import pandas as pd

from wordcloud import WordCloud
from sklearn.feature_extraction.text import CountVectorizer

import matplotlib.pyplot as plt

# %%
# plot the Wordscloud

cv = CountVectorizer(stop_words = 'english')
words = cv.fit_transform(df.clean_tweets)
sum_words = words.sum(axis=0)

words_freq = [(word, sum_words[0, idx]) for word, idx in cv.vocabulary_.items()]
words_freq = sorted(words_freq, key = lambda x: x[1], reverse = True)

wordcloud = WordCloud(background_color = 'lightcyan', width = 2000, height = 2000).generate_from_frequencies(dict(words_freq))

plt.style.use('fivethirtyeight')
plt.figure(figsize=(10, 10))
plt.axis('off')
plt.imshow(wordcloud)
plt.title("Ai from Twitter", fontsize = 20)
plt.show()

# %% [markdown]
# # <font color="green" /> *** Configuration To Scrape A Username ***
# <br />
#
# #### <font color="orange" /> *Config for Username*:
#
# ```
# c = twint.Config()
# c.Pandas = True
# c.Username = "Type Username"
# c.Limit = 1250
# c.Since = "2022-01-01"
# c.Until = "2022-05-20"
# c.Store_csv = True
# ```
#
# Using the 'c.Username = "username" directive, you can search specific users on Twitter.
#
# <br />
#
# <font color="orange" /> E.g.:
# ```
# c.Username = "martin lawrence"
# ```
# <br />
#
# # <font color="FF0000" /> *** Scraping User Data With A Username ***
#
# <br />

# %%
# c = twint.Config()
# c.Pandas = True
# c.Username = "knowledge"
# c.Limit = 1250
# c.Since = "2022-01-01"
# c.Until = "2022-05-20"
# c.Store_csv = True

# %%
# twint.run.Search(c)

# %%
# twint.storage.panda.Tweets_df['tweet'].count()

# %%
# twint.storage.panda.Tweets_df['tweet'][122]

# %%
# twint.storage.panda.Tweets_df.to_csv('username.csv')
# !cp 'username.csv' "gdrive/My Drive/covertsniper/username.csv"

# %% [markdown]
# # <font color="FF0000" />:=--{*** *TWINT CONFIGURATION CODE* ***}--=:
#
# ### Also, don't mind about the c.Username argument or c.Geo argument.<br />
# Since those are only for searching a specific user E.g.: (c.Username = "username").
# <br />Or, Geotags E.g.: (c.Geo = "51.5, -0.127, 15km").
#
# ```
# c = twint.Config()
# c.Pandas = True
# c.Store_csv = True
# c.Search = "knowledge wealthy"
# #c.Username = "username"
# #c.Geo = "51.5, -0.127, 15km"
# c.Limit = 1250
# c.Since = "2022-04-26"
# c.Until = "2022-07-26"
# c.Lang = 'en'```
# ```
# ```
# twint.run.Search(c)
# ```
# ```
# twint.storage.panda.Tweets_df['tweet'].count()
#
# ```
# ```
# twint.storage.panda.Tweets_df['tweet'][122]
#
# ```
# ```
# twint.storage.panda.Tweets_df.to_csv('knowledge wealthy.csv')
# !mv 'knowledge wealthy.csv' "gdrive/My Drive/covertsniper/knowledge wealthy.csv"
# ```
# <br />
#
# #<font color="FF0000" />*** *CUSTOM SCRAPE* ***
#
# <br />

# %%
# c = twint.Config()
# c.Pandas = True
# c.Store_csv = True
# c.Search = "knowledge wealthy"
# #c.Username = "username"
# #c.Geo = "51.5, -0.127, 15km"
# c.Limit = 1250
# c.Since = "2022-04-26"
# c.Until = "2022-07-26"
# c.Lang = 'en'

# %%
# twint.run.Search(c)

# %%
# twint.storage.panda.Tweets_df['tweet'].count()

# %%
# twint.storage.panda.Tweets_df['tweet'][122]

# %%
# twint.storage.panda.Tweets_df.to_csv('knowledge wealthy.csv')
# !mv 'knowledge wealthy.csv' "gdrive/My Drive/covertsniper/knowledge wealthy.csv"

# %% [markdown]
# # <font color="green" /> *** Configuration Geo Tag Scraping ***
#
# You can scrape geotags with the c.Geo command.
#
# <br />
#
# <font color="orange" /> Example:
# ```
# c = twint.Config()
# c.Pandas = True
# c.Geo = "51.5, -0.127, 15km"
# c.Limit = 1250
# c.Search = "bitcoin"
# c.Since = "2022-04-26"
# c.Until = "2022-07-26"
# c.Store_csv = True
# ```
# <br />
#
# <font color="orange" /> E.g:
# ```
# c.Geo = "51.5, -0.127, 15km"
# ```
#
# <br />
# #<font color='FF0000'>*** Scraping Geo Tag Data ***
# <br />

# %%
# c = twint.Config()
# c.Pandas = True
# c.Geo = "51.5, -0.127, 15km"
# c.Limit = 1250
# c.Search = "bitcoin"
# c.Since = "2022-04-26"
# c.Until = "2022-07-26"
# c.Store_csv = True

# %%
# twint.run.Search(c)

# %%
# twint.storage.panda.Tweets_df['tweet'].count()

# %%
# twint.storage.panda.Tweets_df.head()

# %%
# twint.storage.panda.Tweets_df['tweet'][100]
